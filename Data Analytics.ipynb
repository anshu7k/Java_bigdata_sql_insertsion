# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
x=pd.read_csv("C:/Users/Subhanshu/Downloads/US_Accidents_May19.csv")

# %%
x[['ID','Severity']].groupby("Severity").count()
# Out:
#                ID
# Severity
# 0              17
# 1             814
# 2         1455524
# 3          715582
# 4           72002

# %%
from datetime import datetime
b=[datetime.strptime(a, '%Y-%m-%d %H:%M:%S').hour for a in x['Start_Time']]

# %%
pd.DataFrame(b).groupby(0).size()
# Out:
# 0
# 0      16754
# 1      13672
# 2      14492
# 3      14422
# 4      38807
# 5      62428
# 6     125116
# 7     202435
# 8     211224
# 9     136109
# 10    121208
# 11    119595
# 12    108540
# 13    108986
# 14    114615
# 15    134042
# 16    159154
# 17    165068
# 18    125069
# 19     88464
# 20     64268
# 21     43301
# 22     36778
# 23     19392
# dtype: int64

# %%
import time
readable = [time.ctime(a) for a in x['Timestamp']]

# %%
readable[3900000:]
# Out:
# ['Wed Jun  5 09:14:00 2019',
#  'Wed Jun  5 09:15:00 2019',
#  'Wed Jun  5 09:16:00 2019',
#  'Wed Jun  5 09:17:00 2019',
#  'Wed Jun  5 09:18:00 2019',
#  'Wed Jun  5 09:19:00 2019',
#  'Wed Jun  5 09:20:00 2019',
#  'Wed Jun  5 09:21:00 2019',
#  'Wed Jun  5 09:22:00 2019',
#  'Wed Jun  5 09:23:00 2019',
#  'Wed Jun  5 09:24:00 2019',
#  'Wed Jun  5 09:25:00 2019',
#  'Wed Jun  5 09:26:00 2019',
#  'Wed Jun  5 09:27:00 2019',
#  'Wed Jun  5 09:28:00 2019',
#  'Wed Jun  5 09:29:00 2019',
#  'Wed Jun  5 09:30:00 2019',
#  'Wed Jun  5 09:31:00 2019',
#  'Wed Jun  5 09:32:00 2019',
#  'Wed Jun  5 09:33:00 2019',
#  'Wed Jun  5 09:34:00 2019',
#  'Wed Jun  5 09:35:00 2019',
#  'Wed Jun  5 09:36:00 2019',
#  'Wed Jun  5 09:37:00 2019',
#  'Wed Jun  5 09:38:00 2019',
#  'Wed Jun  5 09:39:00 2019',
#  'Wed Jun  5 09:40:00 2019',
#  'Wed Jun  5 09:41:00 2019',
#  'Wed Jun  5 09:42:00 2019',
#  'Wed Jun  5 09:43:00 2019',
#  'Wed Jun  5 09:44:00 2019',
#  'Wed Jun  5 09:45:00 2019',
# ...

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,'lifespan': lifespan}, index=index)

# %%
df
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0
# coyote     69.0      12.0
# horse      88.0      28.0

# %%
ax = df.plot.bar(rot=0)

# %%
import pandas as pd
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],'radius': [2439.7, 6051.8, 6378.1]},index=['Mercury', 'Venus', 'Earth'])

# %%
df
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
p=df.plot.pie(y='mass', figsize=(5, 5))

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x=tips["total_bill"])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips)

# %%
sns.set(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker",palette=["m", "g"],
            data=tips)
